# %% [markdown]
# <a href="https://colab.research.google.com/github/njoysubho/genAI-codespace/blob/main/Llama2_prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook is following the tutorial https://www.youtube.com/watch?v=Z6sCl6abJj4 .
# You need to have HuggingFace Account and an API Token.
# Also, request access for Meta Llama2 https://ai.meta.com/resources/models-and-libraries/llama-downloads/ and then request access for model in Huggingface model hub.

# %%
from transformers import AutoTokenizer
import transformers
import torch

model = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(model,use_auth_token=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:671: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(

# %%
from transformers import pipeline

llama_pipeline = pipeline("text-generation",
                          model = model,
                          torch_dtype = torch.float16,
                          device_map = "auto" )
# Out:
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
def get_llama_response(prompt):
  sequences = llama_pipeline(prompt,
                             do_sample=True,
                             top_k=10,
                             num_return_sequences=4,
                             eos_token_id = tokenizer.eos_token_id,
                             max_length=256)
  print("ChatBot:",sequences[0]['generated_text'])

prompt = "I am new to Gen AI tell me some starting point"
get_llama_response(prompt)
# Out:
# ChatBot: I am new to Gen AI tell me some starting point resources?
#
# I'm glad you're interested in learning more about Generative AI! Here are some starting point resources that you may find helpful:
#
# 1. Books:
# 	* "Generative Adversarial Networks" by Ian Goodfellow, Jean Pouget-Abadie, Mehdi Mirza, and Bing Xu (2014) - This book provides a comprehensive introduction to GANs, including their theory and applications.
# 	* "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville (2016) - This book covers the basics of deep learning, including GANs as a special case of deep learning models.
# 2. Online Courses:
# 	* "Generative Adversarial Networks" by Andrew Ng on Coursera (2019) - This course provides a comprehensive introduction to GANs, including their theory and applications.
# 	* "Deep Learning Specialization" by Andrew Ng on Coursera (2017) - This specialization covers the basics of deep learning, including

# %%
prompt = "If I know AWS, Java, Spring suggest me a career path in Software Engineering"
get_llama_response(prompt)
# Out:
# ChatBot: If I know AWS, Java, Spring suggest me a career path in Software Engineering? 100%. AWS is a cloud computing platform provided by Amazon, and it's a very popular platform in the industry. However, it's not the only platform out there, and it's important to have a well-rounded skill set as a software engineer.
#
# Here are some potential career paths in software engineering that you may want to consider:
#
# 1. Cloud Engineer: With your knowledge of AWS, you could consider a career as a cloud engineer. Cloud engineers design, build, and manage cloud-based systems, including deploying and managing applications, configuring security and networking, and optimizing performance.
# 2. DevOps Engineer: DevOps engineers are responsible for bridging the gap between development and operations, ensuring that software is deployed and running smoothly in production. They may work on automating deployment processes, monitoring and logging, and troubleshooting issues.
# ...
